# %%
import numpy as np

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %%
import numpy as np

# 定义矩阵 A 和 X
A = np.array([[1, 2],
              [3, 4]])

X = np.array([[5, 6],
              [7, 8]])

# %%
A.T
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
X.T @ A == (A.T  @ X).T
# Out:
# array([[ True,  True],
#        [ True,  True]])

# %%
(1,2) (2,3)  # （1, 3）
(3,2) (2,1) # (3, 1)
